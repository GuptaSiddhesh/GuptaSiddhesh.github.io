# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("survey.csv")
data
# Out:
#                Timestamp Enter the grade associated with course ?  [CMSC131]  \
# 0     11/9/2021 23:09:19                                                  A
# 1     11/9/2021 23:28:14                                                  A
# 2     11/9/2021 23:33:15                                                  B
# 3     11/9/2021 23:36:11                                                  A
# 4     11/9/2021 23:40:52                                                  A
# ..                   ...                                                ...
# 161   11/21/2021 0:18:19                                                 B-
# 162  11/22/2021 15:13:02                                      Not Attempted
# 163  11/27/2021 21:19:45                                                  B
# 164    12/2/2021 0:40:43                                                 A+
# 165   12/9/2021 22:38:27                                                 C-
#
# ...

# %%
for i, row in data.iterrows():
    txt = "User{0}"
    data['Timestamp'][i] = txt.format(i) 

data.columns=["Users", "CMSC131", "CMSC132", "CMSC216", "CMSC250", "CMSC330", "CMSC351", "MATH140", "MATH141", "MATH240", "MATH241", 
              "STAT400", "CS_Track", "CMSC4XX", "CMSC411", "CMSC412", "CMSC414", "CMSC416", "CMSC417", "CMSC420", "CMSC421",
              "CMSC422", "CMSC423", "CMSC424", "CMSC426", "CMSC427", "CMSC470", "CMSC430", "CMSC433", "CMSC434", "CMSC435", "CMSC436", 
              "CMSC451", "CMSC452", "CMSC454", "CMSC456", "CMSC457", "CMSC460", "CMSC466", "CMSC320", "CMSC425", "CMSC472", 
              "CMSC473", "CMSC474", "CMSC475", "Graduated"]

data
# Out:
#        Users        CMSC131        CMSC132        CMSC216        CMSC250  \
# 0      User0              A              A              A              A
# 1      User1              A             A-             A-              A
# 2      User2              B             B-              B             C+
# 3      User3              A             B+             B-              B
# 4      User4              A              A             A-              A
# ..       ...            ...            ...            ...            ...
# 161  User161             B-             C+             A+              B
# 162  User162  Not Attempted  Not Attempted  Not Attempted  Not Attempted
# 163  User163              B              B              B              A
# 164  User164             A+             A+              A              A
# 165  User165             C-              B  Not Attempted  Not Attempted
#
#            CMSC330        CMSC351        MATH140        MATH141  \
# ...

# %%
## Upper Level CS Class Data Separation
# Out:
# '11/9/2021 23:09:19'

# %%
data['CMSC131'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['CMSC132'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['CMSC216'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['CMSC250'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['CMSC351'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['CMSC330'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
